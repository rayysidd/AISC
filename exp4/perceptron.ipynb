# %%
import numpy as np

# %%
training_data = [
    ([1, 1, 0.7], 1),
    ([1, 0, 0.9], 0),
    ([0, 1, 0.6], 1),
    ([0, 0, 0.95], 0),
]

# %%
training_data[0][0]
# Out:
# [1, 1, 0.7]

# %%
def step_function(x):
    return 1 if x >= 0 else 0

# Initialize weights & bias
np.random.seed(42)
weights = np.random.randn(len(training_data[0][0]))
bias = np.random.randn()

# Training hyperparameters
lr = 0.1
epochs = 100

for epoch in range(epochs):
    total_updates = 0
    for inputs, target in training_data:
        inputs = np.array(inputs)
        z = np.dot(weights, inputs) + bias
        prediction = step_function(z)

        if prediction != target:
            if target == 1:
                weights += lr * target * inputs
                bias += lr
            else:
                weights -= lr * target* inputs
                bias -= lr
            total_updates += 1

    if total_updates == 0:
        print(f"Training complete at epoch {epoch+1} as weight updates are 0")
        break
    print(f"Epoch {epoch+1}, Weight updates: {total_updates}")

print("\nFinal weights:", weights)
print("Final bias:", bias)
# Out:
# Epoch 1, Weight updates: 2
# Epoch 2, Weight updates: 2
# Epoch 3, Weight updates: 2
# Epoch 4, Weight updates: 2
# Epoch 5, Weight updates: 2
# Epoch 6, Weight updates: 2
# Epoch 7, Weight updates: 2
# Epoch 8, Weight updates: 2
# Epoch 9, Weight updates: 2
# Epoch 10, Weight updates: 3
# Epoch 11, Weight updates: 3
# Epoch 12, Weight updates: 3
# Epoch 13, Weight updates: 3
# Epoch 14, Weight updates: 2
# Epoch 15, Weight updates: 3
# Epoch 16, Weight updates: 2
# Epoch 17, Weight updates: 3
# Epoch 18, Weight updates: 1
# Epoch 19, Weight updates: 2
# Epoch 20, Weight updates: 1
# Epoch 21, Weight updates: 2
# Epoch 22, Weight updates: 1
# Epoch 23, Weight updates: 2
# Epoch 24, Weight updates: 1
# Epoch 25, Weight updates: 1
# Epoch 26, Weight updates: 2
# Epoch 27, Weight updates: 1
# Training complete at epoch 28 as weight updates are 0
#
# Final weights: [0.49671415 0.9617357  1.30768854]
# Final bias: -1.6769701435919755

# %%
# --------------------------
# Testing
# --------------------------
print("\nFinal Weights:", weights)
print("Final Bias:", bias)
correct = 0

for inputs, target in training_data:
    inputs = np.array(inputs)
    z = np.dot(weights, inputs) + bias
    prediction = step_function(z)
    print(f"Input: {inputs}, Target: {target}, Predicted class: {'Apple' if prediction == 1 else 'Orange'}")
    if prediction==target:
        correct+=1

print("Total samples:", len(X))
print("Correct predictions:", correct)
print("Accuracy:", correct / len(X))
# Out:
# Final Weights: [0.49671415 0.9617357  1.30768854]
# Final Bias: -1.6769701435919755
# Input: [1.  1.  0.7], Target: 1, Predicted class: Apple
# Input: [1.  0.  0.9], Target: 0, Predicted class: Orange
# Input: [0.  1.  0.6], Target: 1, Predicted class: Apple
# Input: [0.   0.   0.95], Target: 0, Predicted class: Orange
# Total samples: 4
# Correct predictions: 4
# Accuracy: 1.0
